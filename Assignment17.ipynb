# %% [markdown]
# <a href="https://colab.research.google.com/github/samhita13/Python101/blob/main/Assignment17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Create a text file with your own words (input.txt)
# Read the text file
# For each word you find, add it the dictionary (if it is not there in the dictionary)
#                         if it is there in the dictionary, simply update the COUNT
# at the end of the loop, print the KEYs (words) and the VALUE (count)

# Sample output
# Frequecy Table
# ant 4
# bat 3
# zebra 10
# snake 4
try:
  # Empty dictionary
  filedictionary = {}
  with open("goldilocks.txt", "rt") as fileobj:
    for eachline in fileobj:
      # list of words in a line
      linelist = eachline.split(" ")
      for word in linelist:
        # check the word in dictionary
        value = filedictionary.get(word)
        # word is not in dictionary.
        if value == None:
          value = 1
        else:
          # word is present, increase the count
          value = value + 1
        #update the new pair to dictionary
        filedictionary.update({word:value})
    for key in filedictionary:
      print(key,filedictionary[key] )
except FileNotFoundError:
  print('Error: please check if golidlocks.txt is located in current directory')
# Out:
# ﻿The 1
# Story 1
# of 5
# Goldilocks 7
# and 11
# the 34
# Three 1
# Bears
#  1
# Once 1
# upon 2
# a 5
# time, 2
# there 2
# was 7
# little 2
# girl 1
# named 1
# Goldilocks. 1
# She 5
# went 2
# for 1
# walk 1
# in 13
# forest. 2
# Pretty 1
# soon, 1
# she
#  1
# came 2
# house. 1
# knocked 1
# and, 1
# when 2
# no 1
# one 1
# answered, 1
# she 23
# walked 2
# right 1
# in.
#  1
# At 1
# table 1
# kitchen, 1
# were 1
# three 6
# bowls 1
# porridge. 1
# hungry. 1
# tasted 3
# porridge
#  1
# from 2
# first 3
# bowl.
#  2
# "This 4
# porridge 5
# is 6
# too 6
# hot!" 1
# exclaimed.
#  2
# So, 3
# second 3
# cold," 1
# said
#  1
# last 2
# bowl 1
# porridge.
#  1
# "Ahhh, 2
# this 3
# just 4
# right," 2
# said 4
# happily 1
# ate 2
# it 6
# all 3
# up.
#  1
# After 1
# she'd 1
# eaten 1
# bears' 1
# breakfasts 1
# decided 2
# feeling 1
# tired. 1
# into 3
# the
#  1
# living 1
# room 1
# where 1
# saw 2
# chairs. 1
# sat 2
# chair 6
# to 7
# rest 1
# her 1
# feet.
#  1
# big!" 1
# ...
